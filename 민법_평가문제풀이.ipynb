# %% [markdown]
# <a href="https://colab.research.google.com/github/kyujini34/kyujin/blob/master/%EB%AF%BC%EB%B2%95_%ED%8F%89%EA%B0%80%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2주차 문제

# %%
Correct = ['O', 'o', 'ㅇ', '0']
Wrong = ['X', 'x', 'ㄴ']
total = 0

ans1 = input('문제 1: A와 B가 매매계약을 체결했는데 그 대금을 어음으로 지급하기로 약정한 경우, 매매계약이 무효라면 어음행위는 무효인 것이 원칙이다.')
if(ans1 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans2 = input('문제2: 피한정후견인 A에게 한정후견인 B가 존재하는 경우 A는 B의 동의를 얻어 법률행위를 해야 하는 것이 원칙이다.')
if(ans2 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans3 = input('문제3: 3개 이상의 의사표시로 구성되는 계약은 없다.')
if(ans3 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans4 = input('문제4: 상대방 없는 의사표시의 경우에는 법률관계 당사자가 한 사람이다.')
if(ans4 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans5 = input('문제5: 권리를 포기하는 행위는 법률행위가 아니다.')
if(ans5 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans6 = input('문제6: 행위능력은 법률행위와 비법률행위 모두에서 공통적으로 문제되는 개념이다.')
if(ans6 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans7 = input('문제7: 한정후견인에게 대리권이 인정되는 경우가 있다.')
if(ans7 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans8 = input('문제8: 권리의 포기는 출연행위에 해당한다.')
if(ans8 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans9 = input('문제9: 피성년후견인 A가 성년후견 종료의 심판을 받았다면 종료 1개월 전 이후 이루어진 법률행위부터 영향을 미친다.')
if(ans9 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans10 = input('문제10: 보충적 해석은 양 당사자의 진의를 탐구하는 작업이 아니다.')
if(ans10 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans11 = input('문제11: 의사무능력자가 모두 제한능력자는 아니다.')
if(ans11 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans12 = input('문제12: 피특정후견인 A에게 특정후견인 B가 존재한다면 A는 독자적으로 유효하게 법률행위를 할 수 없다.')
if(ans12 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans13 = input('문제13: 강박에 의한 의사표시에서는 의사와 표시가 일치한다.')
if(ans13 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans14 = input('문제14: 민법 제103조와 달리 제104조는 사적자치의 한계를 정하는 기능을 한다.')
if(ans14 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans15 = input('문제15: A가 B에게 증여를 하도록 C가 A를 기망하여 실제로 A가 B에게 증여를 하였다면 이 증여계약은 무효이다.')
if(ans15 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans16 = input('문제16: 규범적 해석이 행해진 후에는 해당 법률행위를 취소할 수 없다.')
if(ans16 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans17 = input('문제17: 제한능력자와 계약을 체결한 사람은 그 법정대리인이 추인을 한 후에라도 자신의 의사표시를 철회할 수 있다.')
if(ans17 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans18 = input('문제18: 성년후견계약이 체결되었더라도 행위능력이 제한되는 것은 아니다.')
if(ans18 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans19 = input('문제19: 미성년자가 단독으로 체결한 계약은 무효이다.')
if(ans19 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans20 = input('문제20: 자연적 해석은 계약서상의 문구보다는 당사자의 실제 의사를 밝히는 것이다.')
if(ans20 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans21 = input("문제21: '법률행위의 부존재'는 무효 여부를 판단할 대상이 없는 경우이다.")
if(ans21 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans22 = input('문제22: 피성년후견인 A에게 성년후견인 B가 있는 경우, A가 B의 동의를 받아 자동차를 매수한 경우 그 매매계약은 유효하다.')
if(ans22 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans23 = input('문제23: 미성년자의 법정대리인으로서 후견인을 두는 경우는 없다.')
if(ans23 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans24 = input('문제24: 법률행위의 내용이 법률행위 당시에 확정되지 않았다는 이유만으로 무효인 것은 것은 아니다.')
if(ans24 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans25 = input('문제25: 출연행위에 대해서는 무상계약에 관한 규정이 준용된다.')
if(ans25 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans26 = input('문제26: 자연적 해석에 의하여 표의자의 진의를 탐지했더라도 언제나 표의자의 진의대로 효력을 발생하는 것은 아니다.')
if(ans26 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans27 = input('문제27: 대출을 받아 다른 사람에게 줄 목적으로 은행과 계약을 체결했다면 이 계약은 원칙적으로 유효하다.')
if(ans27 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans28 = input("문제28:‘권리능력의 존재’는 법률행위의 성립요건이라는 학설이 있다.")
if(ans28 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans29 = input('문제29: 무상행위는 출연행위가 아니다.')
if(ans29 in Wrong):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

ans30 = input("문제30: 의사능력 유무는 연령을 가지고 획일적으로 판단할 수 없다.")
if(ans30 in Correct):
  print('정답입니다.')
  total = total + 10
else:
  print('틀렸습니다.')
  print()

print('총점은 300점 만점', total. '입니다.')
# Out:
# 문제 1: A와 B가 매매계약을 체결했는데 그 대금을 어음으로 지급하기로 약정한 경우, 매매계약이 무효라면 어음행위는 무효인 것이 원칙이다.ㅇ
# 틀렸습니다.
#
# 문제2: 피한정후견인 A에게 한정후견인 B가 존재하는 경우 A는 B의 동의를 얻어 법률행위를 해야 하는 것이 원칙이다.ㄴ
# 정답입니다.
